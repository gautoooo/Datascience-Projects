# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = ''

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %% [markdown]
# #  Inspection of the JSON structure

# %%
import json
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# # 1.Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD)

# %%
df=requests.get("https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?&start_date=2014-01-01&end_date=2014-12-31&api_key=qnh54zghmUSh3agVViUM")

# %% [markdown]
# # 2. Convert the returned JSON object into a Python dictionary

# %%
json_data=df.json()
print('First Inspection \n\n', json_data.keys())
print('\nSecond Inspection \n\n', json_data['dataset'].keys())
print('\nData Extraction \n\n', json_data['dataset']['data'][1:10])
# Out:
# First Inspection
#
#  dict_keys(['dataset'])
#
# Second Inspection
#
#  dict_keys(['id', 'dataset_code', 'database_code', 'name', 'description', 'refreshed_at', 'newest_available_date', 'oldest_available_date', 'column_names', 'frequency', 'type', 'premium', 'limit', 'transform', 'column_index', 'start_date', 'end_date', 'data', 'collapse', 'order', 'database_id'])
#
# Data Extraction
#
#  [['2014-12-29', 21.37, 21.48, 21.12, 21.27, None, 78057.0, 1664603.0, None, None, None], ['2014-12-23', 21.52, 21.52, 21.31, 21.44, None, 53070.0, 1138122.0, None, None, None], ['2014-12-22', 20.7, 21.54, 20.65, 21.43, None, 95472.0, 2030502.0, None, None, None], ['2014-12-19', 20.5, 20.68, 20.2, 20.55, None, 69878.0, 1423603.0, None, None, None], ['2014-12-18', 20.16, 20.55, 20.16, 20.33, None, 56407.0, 1151396.0, None, None, None], ['2014-12-17', 20.01, 20.26, 19.96, 20.2, None, 55311.0, 1113840.0, None, None, None], ['2014-12-16', 20.05, 20.35, 19.83, 20.1, None, 115618.0, 2315260.0, None, None, None], ['2014-12-15', 20.34, 20.5, 19.86, 19.88, None, 92280.0, 1856403.0, None, None, None], ['2014-12-12', 20.4, 20.64, 20.18, 20.32, None, 82923.0, 1687577.0, None, None, None]]

# %%
j_data=json_data['dataset']['data']
j1_data=pd.DataFrame(j_data,columns=json_data['dataset']['column_names'])
j1_data
# Out:
#            Date   Open   High    Low  Close Change  Traded Volume   Turnover  \
# 0    2014-12-30  21.27  21.27  20.97  21.10   None        42065.0   888369.0
# 1    2014-12-29  21.37  21.48  21.12  21.27   None        78057.0  1664603.0
# 2    2014-12-23  21.52  21.52  21.31  21.44   None        53070.0  1138122.0
# 3    2014-12-22  20.70  21.54  20.65  21.43   None        95472.0  2030502.0
# 4    2014-12-19  20.50  20.68  20.20  20.55   None        69878.0  1423603.0
# 5    2014-12-18  20.16  20.55  20.16  20.33   None        56407.0  1151396.0
# 6    2014-12-17  20.01  20.26  19.96  20.20   None        55311.0  1113840.0
# 7    2014-12-16  20.05  20.35  19.83  20.10   None       115618.0  2315260.0
# 8    2014-12-15  20.34  20.50  19.86  19.88   None        92280.0  1856403.0
# 9    2014-12-12  20.40  20.64  20.18  20.32   None        82923.0  1687577.0
# 10   2014-12-11  20.60  20.60  20.20  20.55   None       152041.0  3107296.0
# 11   2014-12-10  20.61  21.14  20.50  20.85   None       102608.0  2140387.0
# 12   2014-12-09  20.64  20.71  20.13  20.50   None       128412.0  2624163.0
# 243  2014-01-14  22.76  22.76  22.30  22.47   None        73573.0  1653009.0
# 244  2014-01-13  23.27  23.27  22.70  22.80   None        73177.0  1671846.0
# 245  2014-01-10  23.31  23.31  22.92  22.99   None        90100.0  2075460.0
# 246  2014-01-09  23.10  23.44  23.05  23.44   None        55237.0  1285266.0
# 247  2014-01-08  22.92  23.32  22.75  23.00   None       118068.0  2719474.0
# 248  2014-01-07  24.30  24.31  22.63  22.80   None       212702.0  4926333.0
# 249  2014-01-06  24.50  24.68  24.23  24.30   None        20469.0   500796.0
# 250  2014-01-03  24.04  24.47  24.03  24.47   None        20503.0   499475.0
# 251  2014-01-02  24.24  24.76  23.77  24.18   None        55735.0  1355658.0
#
#     Last Price of the Day Daily Traded Units Daily Turnover
# 0                    None               None           None
# 1                    None               None           None
# 2                    None               None           None
# 3                    None               None           None
# 4                    None               None           None
# 5                    None               None           None
# 6                    None               None           None
# 7                    None               None           None
# 8                    None               None           None
# 9                    None               None           None
# 10                   None               None           None
# 11                   None               None           None
# 12                   None               None           None
# 13                   None               None           None
# 14                   None               None           None
# 15                   None               None           None
# 16                   None               None           None
# 17                   None               None           None
# 18                   None               None           None
# 19                   None               None           None
# 20                   None               None           None
# 21                   None               None           None
# 22                   None               None           None
# 23                   None               None           None
# 24                   None               None           None
# 25                   None               None           None
# 26                   None               None           None
# 27                   None               None           None
# 28                   None               None           None
# 29                   None               None           None
# ..                    ...                ...            ...
# 222                  None               None           None
# 223                  None               None           None
# 224                  None               None           None
# 225                  None               None           None
# 226                  None               None           None
# 227                  None               None           None
# 228                  None               None           None
# 229                  None               None           None
# 230                  None               None           None
# 231                  None               None           None
# 232                  None               None           None
# 233                  None               None           None
# 234                  None               None           None
# 235                  None               None           None
# 236                  None               None           None
# 237                  None               None           None
# 238                  None               None           None
# 239                  None               None           None
# 240                  None               None           None
# 241                  None               None           None
# 242                  None               None           None
# 243                  None               None           None
# 244                  None               None           None
# 245                  None               None           None
# 246                  None               None           None
# 247                  None               None           None
# 248                  None               None           None
# 249                  None               None           None
# 250                  None               None           None
# 251                  None               None           None
#
# [252 rows x 11 columns]

# %% [markdown]
# # 3.Calculate what the highest and lowest opening prices were for the stock in this period.

# %%
print("The Highest opening price for the stock in this period is {}" .format(j1_data['Open'].max()))
# Out:
# The Highest opening price for the stock in this period is 24.5

# %%
print("The Lowest opening price for the stock in this period is {}" .format(j1_data['Open'].min()))
# Out:
# The Lowest opening price for the stock in this period is 19.76

# %% [markdown]
# # 4.What was the largest change in any one day (based on High and Low price)?

# %%
list_low = []
list_high = []
for i in j_data:
    list_low.append(i[3])
    list_high.append(i[2])
np_list_low = np.array(list_low)
np_list_high = np.array(list_high)

# %%
max(np_list_high-np_list_low)
# Out:
# 2.1400000000000006

# %% [markdown]
# # 5.What was the largest change between any two days (based on Closing Price)?

# %%
list_Close = []
for i in j_data:
    list_Close.append(i[4])

np_list_Close = np.array(list_Close)
print("Largest change between any two days  is  {}".format(max(np_list_Close)- min(np_list_Close)))
# Out:
# Largest change between any two days  is  4.649999999999999

# %% [markdown]
# # 6.What was the average daily trading volume during this year?

# %%
list_Trade = []
for i in j_data:
    list_Trade.append(i[6])

np_list_Trade = np.array(list_Trade)
print("The average daily trading volume during this year  is {}".format(sum(np_list_Trade)/len(np_list_Trade)))
# Out:
# The average daily trading volume during this year  is 50155.206349206346

# %% [markdown]
# # 7.What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the